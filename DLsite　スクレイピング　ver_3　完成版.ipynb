# %% [markdown]
# <a href="https://colab.research.google.com/github/pikuouji/DLsite-scraping/blob/main/DLsite%E3%80%80%E3%82%B9%E3%82%AF%E3%83%AC%E3%82%A4%E3%83%94%E3%83%B3%E3%82%B0%E3%80%80ver_3%E3%80%80%E5%AE%8C%E6%88%90%E7%89%88.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 認証のためのコード
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import requests
from bs4 import BeautifulSoup
from urllib import request

url = "https://docs.google.com/spreadsheets/d/1iA4Fl_dXzTqGXz3lE7zeLIZ1DY_iESmaT02cqGB-I4A/edit#gid=0" #メイン
#url = "https://docs.google.com/spreadsheets/d/1kJni9_m6qxuNPTyCd_PJcCPRjVejMQGeJS6nQY73gMk/edit#gid=0" #コピー
#url = "https://docs.google.com/spreadsheets/d/1hBlx72jgj0k8hm6BpsUp9c4TrRAeSNGloCmJ2tjgO4g/edit#gid=0" #コピー ver.2

ss = gc.open_by_url(url)

st = ss.get_worksheet(0)
list_of_lists = st.get_all_values()
rangelist = len(list_of_lists)

list_of_dicts = st.get_all_records()

listURL = [r["DLsiteリンク"] for r in list_of_dicts]

for x in range (0, rangelist - 1):
  print('進行率','{:.2%}'.format(x / (rangelist - 2)))
  if listURL[x] == "":
    print('-----')
  else:
    print(listURL[x])
    z = 'K' + str(x + 2)

    # スクレイピング
    # URLの指定
    url = listURL[x]
    #ユーザーエージェントの設定（設定必須）
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"}
    # ここでcookieを指定
    cookie = {'age_check_done': '1'}  #クッキーの指定
    #htmlの取得
    response = requests.get(url=url, headers=headers, cookies=cookie)
    html = response.content
    #BeautifulSoupで扱えるようにパースします
    soup = BeautifulSoup(html, "html.parser")

    #要素取得
    table = str.maketrans('','',',円')
    listA = [i.text for i in soup.select('span.price')]
    last = listA.pop()
    last_int = int(last.translate(table))
    print(last)
    print(last_int)
    print(z)
    print('-----')
    st.update_acell(z , last_int)
# Out:
# 進行率 0.00%
# -----
# 進行率 0.69%
# -----
# 進行率 1.39%
# -----
# 進行率 2.08%
# -----
# 進行率 2.78%
# -----
# 進行率 3.47%
# -----
# 進行率 4.17%
# -----
# 進行率 4.86%
# -----
# 進行率 5.56%
# -----
# 進行率 6.25%
# https://www.dlsite.com/pro/work/=/product_id/VJ013396.html
# 11,000円
# 11000
# J11
# -----
# 進行率 6.94%
# https://www.dlsite.com/pro/work/=/product_id/VJ013197.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 4,400円
# 4400
# J12
# -----
# 進行率 7.64%
# https://www.dlsite.com/pro/work/=/product_id/VJ012820.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 13,037円
# 13037
# J13
# -----
# 進行率 8.33%
# -----
# 進行率 9.03%
# -----
# 進行率 9.72%
# -----
# 進行率 10.42%
# -----
# 進行率 11.11%
# -----
# 進行率 11.81%
# -----
# 進行率 12.50%
# https://www.dlsite.com/pro/work/=/product_id/VJ010060.html
# 7,124円
# 7124
# J20
# -----
# 進行率 13.19%
# https://www.dlsite.com/pro/work/=/product_id/VJ010313.html
# 7,124円
# 7124
# J21
# -----
# 進行率 13.89%
# -----
# 進行率 14.58%
# -----
# 進行率 15.28%
# -----
# 進行率 15.97%
# -----
# 進行率 16.67%
# -----
# 進行率 17.36%
# -----
# 進行率 18.06%
# -----
# 進行率 18.75%
# -----
# 進行率 19.44%
# https://www.dlsite.com/soft/work/=/product_id/VJ014002.html
# 1,540円
# 1540
# J30
# -----
# 進行率 20.14%
# -----
# 進行率 20.83%
# -----
# 進行率 21.53%
# -----
# 進行率 22.22%
# -----
# 進行率 22.92%
# -----
# 進行率 23.61%
# https://www.dlsite.com/pro/work/=/product_id/VJ007463.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 5,800円
# 5800
# J36
# -----
# 進行率 24.31%
# -----
# 進行率 25.00%
# -----
# 進行率 25.69%
# -----
# 進行率 26.39%
# https://www.dlsite.com/pro/work/=/product_id/VJ014738.html
# 7,980円
# 7980
# J40
# -----
# 進行率 27.08%
# https://www.dlsite.com/pro/work/=/product_id/VJ011419.html
# 7,920円
# 7920
# J41
# -----
# 進行率 27.78%
# https://www.dlsite.com/pro/work/=/product_id/VJ013367.html
# 7,920円
# 7920
# J42
# -----
# 進行率 28.47%
# https://www.dlsite.com/pro/work/=/product_id/VJ010331.html
# 7,920円
# 7920
# J43
# -----
# 進行率 29.17%
# https://www.dlsite.com/pro/work/=/product_id/VJ006600.html
# 6,930円
# 6930
# J44
# -----
# 進行率 29.86%
# -----
# 進行率 30.56%
# -----
# 進行率 31.25%
# -----
# 進行率 31.94%
# -----
# 進行率 32.64%
# -----
# 進行率 33.33%
# https://www.dlsite.com/pro/work/=/product_id/VJ013906.html
# 7,920円
# 7920
# J50
# -----
# 進行率 34.03%
# https://www.dlsite.com/pro/work/=/product_id/VJ012243.html
# 5,561円
# 5561
# J51
# -----
# 進行率 34.72%
# https://www.dlsite.com/pro/work/=/product_id/VJ010018.html
# 7,945円
# 7945
# J52
# -----
# 進行率 35.42%
# https://www.dlsite.com/pro/work/=/product_id/VJ011306.html
# 5,561円
# 5561
# J53
# -----
# 進行率 36.11%
# https://www.dlsite.com/pro/work/=/product_id/VJ011570.html
# 15,074円
# 15074
# J54
# -----
# 進行率 36.81%
# -----
# 進行率 37.50%
# -----
# 進行率 38.19%
# -----
# 進行率 38.89%
# -----
# 進行率 39.58%
# -----
# 進行率 40.28%
# -----
# 進行率 40.97%
# -----
# 進行率 41.67%
# -----
# 進行率 42.36%
# -----
# 進行率 43.06%
# https://www.dlsite.com/soft/work/=/product_id/VJ013550.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 8,910円
# 8910
# J64
# -----
# 進行率 43.75%
# https://www.dlsite.com/soft/work/=/product_id/VJ014144.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 1,980円
# 1980
# J65
# -----
# 進行率 44.44%
# -----
# 進行率 45.14%
# -----
# 進行率 45.83%
# -----
# 進行率 46.53%
# -----
# 進行率 47.22%
# https://www.dlsite.com/pro/work/=/product_id/VJ012598.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 8,910円
# 8910
# J70
# -----
# 進行率 47.92%
# https://www.dlsite.com/pro/work/=/product_id/VJ010335.html
# 8,580円
# 8580
# J71
# -----
# 進行率 48.61%
# https://www.dlsite.com/pro/work/=/product_id/VJ014500.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 6,050円
# 6050
# J72
# -----
# 進行率 49.31%
# -----
# 進行率 50.00%
# -----
# 進行率 50.69%
# -----
# 進行率 51.39%
# -----
# 進行率 52.08%
# -----
# 進行率 52.78%
# -----
# 進行率 53.47%
# https://www.dlsite.com/pro/work/=/product_id/VJ008029.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 7,124円
# 7124
# J79
# -----
# 進行率 54.17%
# https://www.dlsite.com/pro/work/=/product_id/VJ009267.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 7,124円
# 7124
# J80
# -----
# 進行率 54.86%
# -----
# 進行率 55.56%
# -----
# 進行率 56.25%
# -----
# 進行率 56.94%
# -----
# 進行率 57.64%
# -----
# 進行率 58.33%
# -----
# 進行率 59.03%
# -----
# 進行率 59.72%
# -----
# 進行率 60.42%
# -----
# 進行率 61.11%
# -----
# 進行率 61.81%
# -----
# 進行率 62.50%
# -----
# 進行率 63.19%
# -----
# 進行率 63.89%
# https://www.dlsite.com/pro/work/=/product_id/VJ010308.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 6,380円
# 6380
# J94
# -----
# 進行率 64.58%
# -----
# 進行率 65.28%
# -----
# 進行率 65.97%
# -----
# 進行率 66.67%
# -----
# 進行率 67.36%
# -----
# 進行率 68.06%
# -----
# 進行率 68.75%
# -----
# 進行率 69.44%
# -----
# 進行率 70.14%
# -----
# 進行率 70.83%
# -----
# 進行率 71.53%
# -----
# 進行率 72.22%
# -----
# 進行率 72.92%
# -----
# 進行率 73.61%
# -----
# 進行率 74.31%
# -----
# 進行率 75.00%
# -----
# 進行率 75.69%
# -----
# 進行率 76.39%
# -----
# 進行率 77.08%
# -----
# 進行率 77.78%
# -----
# 進行率 78.47%
# https://www.dlsite.com/pro/work/=/product_id/VJ014841.html
# 7,700円
# 7700
# J115
# -----
# 進行率 79.17%
# -----
# 進行率 79.86%
# -----
# 進行率 80.56%
# -----
# 進行率 81.25%
# -----
# 進行率 81.94%
# https://www.dlsite.com/home/work/=/product_id/RJ297925.html
# 4,180円
# 4180
# J120
# -----
# 進行率 82.64%
# -----
# 進行率 83.33%
# -----
# 進行率 84.03%
# -----
# 進行率 84.72%
# -----
# 進行率 85.42%
# -----
# 進行率 86.11%
# -----
# 進行率 86.81%
# -----
# 進行率 87.50%
# -----
# 進行率 88.19%
# -----
# 進行率 88.89%
# -----
# 進行率 89.58%
# -----
# 進行率 90.28%
# -----
# 進行率 90.97%
# -----
# 進行率 91.67%
# https://www.dlsite.com/pro/work/=/product_id/VJ008278.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 5,029円
# 5029
# J134
# -----
# 進行率 92.36%
# -----
# 進行率 93.06%
# -----
# 進行率 93.75%
# -----
# 進行率 94.44%
# https://www.dlsite.com/pro/work/=/product_id/VJ011656.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 2,530円
# 2530
# J138
# -----
# 進行率 95.14%
# https://www.dlsite.com/pro/work/=/product_id/VJ011029.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 7,480円
# 7480
# J139
# -----
# 進行率 95.83%
# -----
# 進行率 96.53%
# -----
# 進行率 97.22%
# -----
# 進行率 97.92%
# -----
# 進行率 98.61%
# -----
# 進行率 99.31%
# -----
# 進行率 100.00%
# https://www.dlsite.com/pro/work/=/product_id/VJ013726.html/?unique_op=af&utm_medium=affiliate&utm_source=erogamescape.dyndns.org%2F
# 6,000円
# 6000
# J146
# -----
